# %%
import os
path=os.chdir("/content/drive/MyDrive/Dataset/mcl")
# from google.colab import drive
# drive.mount('/content/drive')

i=1
for file in os.listdir(path):
  newfile="mcl_{}.jpg".format(i)
  os.rename(file,newfile)
  i=i+1
